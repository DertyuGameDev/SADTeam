# %%
import os

import ast
import pandas as pd
import numpy as np
import seaborn as sns
from ydata_profiling import ProfileReport

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
current_dir = os.getcwd()
print(current_dir)
# Out:
# D:\code_files\Python\data_analysis_yandex\yandex_final\git\SADTeam\Настя

# %%
! pip install -U ydata-profiling
# !{sys.executable} -m pip install -U ydata-profiling
! pip install jupyter-contrib-nbextensions
! jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ydata-profiling in d:\anaconda3\lib\site-packages (4.16.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in d:\anaconda3\lib\site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in d:\anaconda3\lib\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in d:\anaconda3\lib\site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=2 in d:\anaconda3\lib\site-packages (from ydata-profiling) (2.5.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in d:\anaconda3\lib\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in d:\anaconda3\lib\site-packages (from ydata-profiling) (3.1.4)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in d:\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in d:\anaconda3\lib\site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in d:\anaconda3\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in d:\anaconda3\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in d:\anaconda3\lib\site-packages (from ydata-profiling) (2.32.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in d:\anaconda3\lib\site-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in d:\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in d:\anaconda3\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in d:\anaconda3\lib\site-packages (from ydata-profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in d:\anaconda3\lib\site-packages (from ydata-profiling) (4.4.2)
# Requirement already satisfied: imagehash==4.3.1 in d:\anaconda3\lib\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in d:\anaconda3\lib\site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in d:\anaconda3\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in d:\anaconda3\lib\site-packages (from ydata-profiling) (0.59.1)
# Requirement already satisfied: PyWavelets in d:\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.5.0)
# Requirement already satisfied: pillow in d:\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in d:\anaconda3\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in d:\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in d:\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.6 in d:\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in d:\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in d:\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.2.1)
# Requirement already satisfied: puremagic in d:\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.28)
# Requirement already satisfied: six in d:\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# "{sys.executable}" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# Requirement already satisfied: jupyter-contrib-nbextensions in d:\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: ipython-genutils in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.4.2)
# Requirement already satisfied: jupyter-core in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.7.2)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (7.10.0)
# Requirement already satisfied: notebook>=6.0 in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (7.0.8)
# Requirement already satisfied: tornado in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (6.4.1)
# Requirement already satisfied: traitlets>=4.1 in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.14.3)
# Requirement already satisfied: lxml in d:\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions) (5.2.1)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from jupyter-contrib-core>=0.3.3->jupyter-contrib-nbextensions) (69.5.1)
# Requirement already satisfied: jupyter-server in d:\anaconda3\lib\site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.14.1)
# Requirement already satisfied: pyyaml in d:\anaconda3\lib\site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (4.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (5.9.2)
# Requirement already satisfied: packaging in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (2.15.1)
# Requirement already satisfied: tinycss2 in d:\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter-contrib-nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda3\lib\site-packages (from jupyter-core->jupyter-contrib-nbextensions) (3.10.0)
# Requirement already satisfied: pywin32>=300 in d:\anaconda3\lib\site-packages (from jupyter-core->jupyter-contrib-nbextensions) (305.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in d:\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in d:\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in d:\anaconda3\lib\site-packages (from notebook>=6.0->jupyter-contrib-nbextensions) (0.2.3)
# Requirement already satisfied: six>=1.9.0 in d:\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in d:\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter-contrib-nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\anaconda3\lib\site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: ipykernel in d:\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.0)
# Requirement already satisfied: babel>=2.10 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (4.19.2)
# Requirement already satisfied: requests>=2.31 in d:\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.32.2)
# Requirement already satisfied: fastjsonschema in d:\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.16.2)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter-contrib-nbextensions) (2.5)
# Requirement already satisfied: idna>=2.8 in d:\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (3.7)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in d:\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2024.1)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in d:\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter-contrib-nbextensions) (2024.8.30)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in d:\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in d:\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (8.25.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in d:\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (1.6.0)
# Requirement already satisfied: psutil in d:\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (5.9.0)
# Requirement already satisfied: decorator in d:\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (3.0.43)
# Requirement already satisfied: stack-data in d:\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.0)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.4.6)
# Requirement already satisfied: fqdn in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.1)
# Requirement already satisfied: uri-template in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in d:\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.16.0)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in d:\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in d:\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter-contrib-nbextensions) (1.2.3)
# Requirement already satisfied: executing in d:\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in d:\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (2.0.5)
# Requirement already satisfied: pure-eval in d:\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter-contrib-nbextensions) (0.2.2)
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console contrib dejavu events execute kernel kernelspec
# lab labextension labhub migrate nbconvert nbextensions_configurator notebook
# qtconsole run script server troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %%
PATH_OUT = r'D:\code_files\Python\data_analysis_yandex\yandex_final\git\SADTeam\Настя'

# %%
df = pd.read_csv(PATH_OUT + '\\rides.csv', sep=',', encoding='utf-8', skipinitialspace=True, decimal=',')
df
# Out:
#             Id           Start Date             End Date Start Location  \
# 0       100340  2023-04-22 09:01:03  2023-04-22 09:24:45       Шевченко
# 1       100341  2023-04-22 09:01:07  2023-04-22 09:29:32         Чехова
# 2       100342  2023-04-22 09:04:27  2023-04-22 09:42:46      Буденного
# 3       100343  2023-04-22 09:06:34  2023-04-22 09:38:23          Труда
# 4       100344  2023-04-22 09:09:27  2023-04-22 09:40:07   Первомайская
# ...        ...                  ...                  ...            ...
# 102250  197707  2023-07-31 23:45:06  2023-08-01 00:06:55        Озерная
# 102251  197708  2023-07-31 23:46:01  2023-08-01 00:25:35       Мичурина
# 102252  197709  2023-07-31 23:48:04  2023-08-01 00:09:21     Лермонтова
# 102253  197710  2023-07-31 23:51:41  2023-08-01 00:38:04      Рябиновая
# 102254  197711  2023-07-31 23:57:01  2023-08-01 00:19:03     Молодежная
#
#          Start District  End Location     End District Distance  Promo
# 0         Юго-Восточный       Майская      Октябрьский   4069.0      0
# 1              заречный    Спортивная      октябрьский   4515.0      0
# 2           Октябрьский      Суворова        ленинский   4520.0      0
# 3           Центральный       Рабочая  Северо-Западный   3881.0      0
# 4       Северо-Западный     Юбилейная    Юго-Восточный   4029.0      0
# ...                 ...           ...              ...      ...    ...
# 102250    Юго-Восточный  Первомайская  Северо-Западный   3302.0      0
# 102251        Ленинский       Садовая         Заречный   4992.0      0
# 102252        ленинский     Куйбышева      Центральный   2781.0      0
# 102253  Северо-Западный   Энергетиков    Юго-Восточный   6466.0      0
# 102254    Юго-Восточный   Маяковского      Центральный   3561.0      0
#
# [102255 rows x 9 columns]

# %%
df1 = df.copy()
df2 = df.copy()

# %%
df2['Start Date'] = pd.to_datetime(df2['Start Date'])
df2['End Date'] = pd.to_datetime(df2['End Date'])

# %%
df2['Start Month'] = df2['Start Date'].dt.month
df2['End Month'] = df2['End Date'].dt.month
seasons = {
    12: 'Зима', 1: 'Зима', 2: 'Зима',
    3: 'Весна', 4: 'Весна', 5: 'Весна',
    6: 'Лето', 7: 'Лето', 8: 'Лето',
    9: 'Осень', 10: 'Осень', 11: 'Осень'
}
df2['Start Season'] = df2['Start Month'].map(seasons)
df2['End Season'] = df2['End Month'].map(seasons)
df2
# Out:
#             Id          Start Date            End Date Start Location  \
# 0       100340 2023-04-22 09:01:03 2023-04-22 09:24:45       Шевченко
# 1       100341 2023-04-22 09:01:07 2023-04-22 09:29:32         Чехова
# 2       100342 2023-04-22 09:04:27 2023-04-22 09:42:46      Буденного
# 3       100343 2023-04-22 09:06:34 2023-04-22 09:38:23          Труда
# 4       100344 2023-04-22 09:09:27 2023-04-22 09:40:07   Первомайская
# ...        ...                 ...                 ...            ...
# 102250  197707 2023-07-31 23:45:06 2023-08-01 00:06:55        Озерная
# 102251  197708 2023-07-31 23:46:01 2023-08-01 00:25:35       Мичурина
# 102252  197709 2023-07-31 23:48:04 2023-08-01 00:09:21     Лермонтова
# 102253  197710 2023-07-31 23:51:41 2023-08-01 00:38:04      Рябиновая
# 102254  197711 2023-07-31 23:57:01 2023-08-01 00:19:03     Молодежная
#
#          Start District  End Location     End District Distance  Promo  \
# 0         Юго-Восточный       Майская      Октябрьский   4069.0      0
# 1              заречный    Спортивная      октябрьский   4515.0      0
# 2           Октябрьский      Суворова        ленинский   4520.0      0
# 3           Центральный       Рабочая  Северо-Западный   3881.0      0
# 4       Северо-Западный     Юбилейная    Юго-Восточный   4029.0      0
# ...                 ...           ...              ...      ...    ...
# 102250    Юго-Восточный  Первомайская  Северо-Западный   3302.0      0
# 102251        Ленинский       Садовая         Заречный   4992.0      0
# 102252        ленинский     Куйбышева      Центральный   2781.0      0
# 102253  Северо-Западный   Энергетиков    Юго-Восточный   6466.0      0
# 102254    Юго-Восточный   Маяковского      Центральный   3561.0      0
#
#         Start Month  End Month Start Season End Season
# 0                 4        4.0        Весна      Весна
# 1                 4        4.0        Весна      Весна
# 2                 4        4.0        Весна      Весна
# 3                 4        4.0        Весна      Весна
# 4                 4        4.0        Весна      Весна
# ...             ...        ...          ...        ...
# 102250            7        8.0         Лето       Лето
# 102251            7        8.0         Лето       Лето
# 102252            7        8.0         Лето       Лето
# 102253            7        8.0         Лето       Лето
# 102254            7        8.0         Лето       Лето
#
# [102255 rows x 13 columns]

# %%
df2['Time start'] = df2['Start Date'].dt.time
df2['Time end'] = df2['End Date'].dt.time
df2['Trip Duration'] = (df2['End Date'] - df2['Start Date']).dt.total_seconds() / 60
df2
# Out:
#             Id          Start Date            End Date Start Location  \
# 0       100340 2023-04-22 09:01:03 2023-04-22 09:24:45       Шевченко
# 1       100341 2023-04-22 09:01:07 2023-04-22 09:29:32         Чехова
# 2       100342 2023-04-22 09:04:27 2023-04-22 09:42:46      Буденного
# 3       100343 2023-04-22 09:06:34 2023-04-22 09:38:23          Труда
# 4       100344 2023-04-22 09:09:27 2023-04-22 09:40:07   Первомайская
# ...        ...                 ...                 ...            ...
# 102250  197707 2023-07-31 23:45:06 2023-08-01 00:06:55        Озерная
# 102251  197708 2023-07-31 23:46:01 2023-08-01 00:25:35       Мичурина
# 102252  197709 2023-07-31 23:48:04 2023-08-01 00:09:21     Лермонтова
# 102253  197710 2023-07-31 23:51:41 2023-08-01 00:38:04      Рябиновая
# 102254  197711 2023-07-31 23:57:01 2023-08-01 00:19:03     Молодежная
#
#          Start District  End Location     End District Distance  Promo  \
# 0         Юго-Восточный       Майская      Октябрьский   4069.0      0
# 1              заречный    Спортивная      октябрьский   4515.0      0
# 2           Октябрьский      Суворова        ленинский   4520.0      0
# 3           Центральный       Рабочая  Северо-Западный   3881.0      0
# 4       Северо-Западный     Юбилейная    Юго-Восточный   4029.0      0
# ...                 ...           ...              ...      ...    ...
# 102250    Юго-Восточный  Первомайская  Северо-Западный   3302.0      0
# 102251        Ленинский       Садовая         Заречный   4992.0      0
# 102252        ленинский     Куйбышева      Центральный   2781.0      0
# 102253  Северо-Западный   Энергетиков    Юго-Восточный   6466.0      0
# 102254    Юго-Восточный   Маяковского      Центральный   3561.0      0
#
#         Start Month  End Month Start Season End Season Time start  Time end  \
# 0                 4        4.0        Весна      Весна   09:01:03  09:24:45
# 1                 4        4.0        Весна      Весна   09:01:07  09:29:32
# 2                 4        4.0        Весна      Весна   09:04:27  09:42:46
# 3                 4        4.0        Весна      Весна   09:06:34  09:38:23
# 4                 4        4.0        Весна      Весна   09:09:27  09:40:07
# ...             ...        ...          ...        ...        ...       ...
# 102250            7        8.0         Лето       Лето   23:45:06  00:06:55
# 102251            7        8.0         Лето       Лето   23:46:01  00:25:35
# 102252            7        8.0         Лето       Лето   23:48:04  00:09:21
# 102253            7        8.0         Лето       Лето   23:51:41  00:38:04
# 102254            7        8.0         Лето       Лето   23:57:01  00:19:03
#
#         Trip Duration
# 0           23.700000
# 1           28.416667
# 2           38.316667
# 3           31.816667
# 4           30.666667
# ...               ...
# 102250      21.816667
# 102251      39.566667
# 102252      21.283333
# 102253      46.383333
# 102254      22.033333
#
# [102255 rows x 16 columns]

# %%
df2['Distance'] = pd.to_numeric(df2['Distance'], errors='coerce')
df2['Speed (km/h)'] = (df2['Distance'] / 1000) / (df2['Trip Duration'] / 60)

df2.head(10)
# Out:
#        Id          Start Date            End Date Start Location  \
# 0  100340 2023-04-22 09:01:03 2023-04-22 09:24:45       Шевченко
# 1  100341 2023-04-22 09:01:07 2023-04-22 09:29:32         Чехова
# 2  100342 2023-04-22 09:04:27 2023-04-22 09:42:46      Буденного
# 3  100343 2023-04-22 09:06:34 2023-04-22 09:38:23          Труда
# 4  100344 2023-04-22 09:09:27 2023-04-22 09:40:07   Первомайская
# 5  100345 2023-04-22 09:10:09 2023-04-22 09:49:56         Лесная
# 6  100346 2023-04-22 09:15:12 2023-04-22 09:26:01   Пролетарская
# 7  100347 2023-04-22 09:19:13 2023-04-22 09:40:03       Комарова
# 8  100348 2023-04-22 09:21:42 2023-04-22 09:39:04       Западная
# 9  100349 2023-04-22 09:28:00 2023-04-22 10:02:08        Свободы
#
#     Start District  End Location     End District  Distance  Promo  \
# 0    Юго-Восточный       Майская      Октябрьский    4069.0      0
# 1         заречный    Спортивная      октябрьский    4515.0      0
# 2      Октябрьский      Суворова        ленинский    4520.0      0
# 3      Центральный       Рабочая  Северо-Западный    3881.0      0
# 4  Северо-Западный     Юбилейная    Юго-Восточный    4029.0      0
# 5    Юго-Восточный      Западная        Ленинский    4879.0      0
# 6      Центральный       Свободы        Ленинский    1846.0      0
# 7        Ленинский  ул. западная        Ленинский    3133.0      0
# 8        ленинский       Озерная    Юго-Восточный       3.0      0
# 9        ленинский   ул. чкалова    юго-восточный    5263.0      0
#
#    Start Month  End Month Start Season End Season Time start  Time end  \
# 0            4        4.0        Весна      Весна   09:01:03  09:24:45
# 1            4        4.0        Весна      Весна   09:01:07  09:29:32
# 2            4        4.0        Весна      Весна   09:04:27  09:42:46
# 3            4        4.0        Весна      Весна   09:06:34  09:38:23
# 4            4        4.0        Весна      Весна   09:09:27  09:40:07
# 5            4        4.0        Весна      Весна   09:10:09  09:49:56
# 6            4        4.0        Весна      Весна   09:15:12  09:26:01
# 7            4        4.0        Весна      Весна   09:19:13  09:40:03
# 8            4        4.0        Весна      Весна   09:21:42  09:39:04
# 9            4        4.0        Весна      Весна   09:28:00  10:02:08
#
#    Trip Duration  Speed (km/h)
# 0      23.700000     10.301266
# 1      28.416667      9.533138
# 2      38.316667      7.077860
# 3      31.816667      7.318806
# 4      30.666667      7.882826
# 5      39.783333      7.358358
# 6      10.816667     10.239753
# 7      20.833333      9.023040
# 8      17.366667      0.010365
# 9      34.133333      9.251367

# %%
# Фильтруем аномальные значения
df_filtered = df2[df2['Distance'] < 2000000]

# Создаем графики в одном месте
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Boxplot (вертикальный)
sns.boxplot(y=df_filtered['Distance'], ax=axes[0], color='skyblue')
axes[0].set_title('Boxplot of Distance')

# Histplot
sns.histplot(df_filtered['Distance'], kde=True, ax=axes[1], color='orange')
axes[1].set_title('Histogram of Distance')

plt.tight_layout()
plt.show()

# %%
gap = df2['Distance'][df2['Distance'] > 3000000].count()
df22 = df2[df2['Speed (km/h)'] <= 60]
df22
# Out:
#             Id          Start Date            End Date Start Location  \
# 0       100340 2023-04-22 09:01:03 2023-04-22 09:24:45       Шевченко
# 1       100341 2023-04-22 09:01:07 2023-04-22 09:29:32         Чехова
# 2       100342 2023-04-22 09:04:27 2023-04-22 09:42:46      Буденного
# 3       100343 2023-04-22 09:06:34 2023-04-22 09:38:23          Труда
# 4       100344 2023-04-22 09:09:27 2023-04-22 09:40:07   Первомайская
# ...        ...                 ...                 ...            ...
# 102250  197707 2023-07-31 23:45:06 2023-08-01 00:06:55        Озерная
# 102251  197708 2023-07-31 23:46:01 2023-08-01 00:25:35       Мичурина
# 102252  197709 2023-07-31 23:48:04 2023-08-01 00:09:21     Лермонтова
# 102253  197710 2023-07-31 23:51:41 2023-08-01 00:38:04      Рябиновая
# 102254  197711 2023-07-31 23:57:01 2023-08-01 00:19:03     Молодежная
#
#          Start District  End Location     End District  Distance  Promo  \
# 0         Юго-Восточный       Майская      Октябрьский    4069.0      0
# 1              заречный    Спортивная      октябрьский    4515.0      0
# 2           Октябрьский      Суворова        ленинский    4520.0      0
# 3           Центральный       Рабочая  Северо-Западный    3881.0      0
# 4       Северо-Западный     Юбилейная    Юго-Восточный    4029.0      0
# ...                 ...           ...              ...       ...    ...
# 102250    Юго-Восточный  Первомайская  Северо-Западный    3302.0      0
# 102251        Ленинский       Садовая         Заречный    4992.0      0
# 102252        ленинский     Куйбышева      Центральный    2781.0      0
# 102253  Северо-Западный   Энергетиков    Юго-Восточный    6466.0      0
# 102254    Юго-Восточный   Маяковского      Центральный    3561.0      0
#
#         Start Month  End Month Start Season End Season Time start  Time end  \
# 0                 4        4.0        Весна      Весна   09:01:03  09:24:45
# 1                 4        4.0        Весна      Весна   09:01:07  09:29:32
# 2                 4        4.0        Весна      Весна   09:04:27  09:42:46
# 3                 4        4.0        Весна      Весна   09:06:34  09:38:23
# 4                 4        4.0        Весна      Весна   09:09:27  09:40:07
# ...             ...        ...          ...        ...        ...       ...
# 102250            7        8.0         Лето       Лето   23:45:06  00:06:55
# 102251            7        8.0         Лето       Лето   23:46:01  00:25:35
# 102252            7        8.0         Лето       Лето   23:48:04  00:09:21
# 102253            7        8.0         Лето       Лето   23:51:41  00:38:04
# 102254            7        8.0         Лето       Лето   23:57:01  00:19:03
#
#         Trip Duration  Speed (km/h)
# 0           23.700000     10.301266
# 1           28.416667      9.533138
# 2           38.316667      7.077860
# 3           31.816667      7.318806
# 4           30.666667      7.882826
# ...               ...           ...
# 102250      21.816667      9.081131
# 102251      39.566667      7.570008
# 102252      21.283333      7.839937
# 102253      46.383333      8.364211
# 102254      22.033333      9.697126
#
# [99823 rows x 17 columns]

# %%
df_filtered = df22[df22['Distance'] < 2000000]

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

sns.boxplot(y=df_filtered['Distance'], ax=axes[0], color='skyblue')
axes[0].set_title('Boxplot of Distance')

sns.histplot(df_filtered['Distance'], kde=True, ax=axes[1], color='orange')
axes[1].set_title('Histogram of Distance')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Start Season', data=df2, order=['Зима', 'Весна', 'Лето', 'Осень'])
plt.title('Распределение поездок по сезонам')
plt.xlabel('Сезон')
plt.ylabel('Количество поездок')
plt.show()

# %%
profile = ProfileReport(
    df1, 
    title="Profiling Report", 
    correlations={
        "auto": {"calculate": False},
        "pearson": {"calculate": True},
        "spearman": {"calculate": True},
        "kendall": {"calculate": True},
        "phi_k": {"calculate": True},
        "cramers": {"calculate": True}
    }
)

# %%
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|                                                                                            | 0/9 [00:00<?, ?it/s]
#  11%|█████████▎                                                                          | 1/9 [00:02<00:18,  2.35s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:03<00:00,  2.57it/s]
